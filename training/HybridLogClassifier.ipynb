# %%
import pandas as pd

# %%
df = pd.read_csv('synthetic_logs.csv')

# %%
df
# Out:
#                 timestamp           source  \
# 0     2025-06-27 07:20:25        ModernCRM
# 1         1/14/2025 23:07        ModernCRM
# 2          1/17/2025 1:29  AnalyticsEngine
# 3     2025-07-12 00:24:16         ModernHR
# 4     2025-06-02 18:25:23    BillingSystem
# ...                   ...              ...
# 2405  2025-08-13 07:29:25         ModernHR
# 2406       1/11/2025 5:32         ModernHR
# 2407  2025-08-03 03:07:47    ThirdPartyAPI
# 2408     11/11/2025 11:52    BillingSystem
# 2409     12/25/2025 13:21  AnalyticsEngine
#
#                                             log_message    target_label  \
# 0     nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1        Email service experiencing issues with sending  Critical Error
# 2             Unauthorized access to data was attempted  Security Alert
# 3     nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4     nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status
# ...                                                 ...             ...
# 2405  nova.osapi_compute.wsgi.server [req-96c3ec98-2...     HTTP Status
# 2406  User 3844 account experienced multiple failed ...  Security Alert
# 2407  nova.metadata.wsgi.server [req-b6d4a270-accb-4...     HTTP Status
# 2408      Email service affected by failed transmission  Critical Error
# 2409  Repeated failed login attempts occurred for us...  Security Alert
#
#      complexity
# 0          bert
# 1          bert
# 2          bert
# 3          bert
# 4          bert
# ...         ...
# 2405       bert
# 2406       bert
# 2407       bert
# 2408       bert
# 2409       bert
#
# [2410 rows x 5 columns]

# %%
df.drop('complexity', axis=1)
# Out:
#                 timestamp           source  \
# 0     2025-06-27 07:20:25        ModernCRM
# 1         1/14/2025 23:07        ModernCRM
# 2          1/17/2025 1:29  AnalyticsEngine
# 3     2025-07-12 00:24:16         ModernHR
# 4     2025-06-02 18:25:23    BillingSystem
# ...                   ...              ...
# 2405  2025-08-13 07:29:25         ModernHR
# 2406       1/11/2025 5:32         ModernHR
# 2407  2025-08-03 03:07:47    ThirdPartyAPI
# 2408     11/11/2025 11:52    BillingSystem
# 2409     12/25/2025 13:21  AnalyticsEngine
#
#                                             log_message    target_label  \
# 0     nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1        Email service experiencing issues with sending  Critical Error
# 2             Unauthorized access to data was attempted  Security Alert
# 3     nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4     nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status
# ...                                                 ...             ...
# 2405  nova.osapi_compute.wsgi.server [req-96c3ec98-2...     HTTP Status
# 2406  User 3844 account experienced multiple failed ...  Security Alert
# 2407  nova.metadata.wsgi.server [req-b6d4a270-accb-4...     HTTP Status
# 2408      Email service affected by failed transmission  Critical Error
# 2409  Repeated failed login attempts occurred for us...  Security Alert
#
#       cluster_label
# 0                 0
# 1                 1
# 2                 2
# 3                 0
# 4                 0
# ...             ...
# 2405              0
# 2406              7
# 2407              0
# 2408              1
# 2409              7
#
# [2410 rows x 5 columns]

# %%
df.source.unique()
# Out:
# array(['ModernCRM', 'AnalyticsEngine', 'ModernHR', 'BillingSystem',
#        'ThirdPartyAPI', 'LegacyCRM'], dtype=object)

# %%
df.target_label.unique()
# Out:
# array(['HTTP Status', 'Critical Error', 'Security Alert', 'Error',
#        'System Notification', 'Resource Usage', 'User Action',
#        'Workflow Error', 'Deprecation Warning'], dtype=object)

# %% [markdown]
# #### How do you find out where you can use regex?
# We need to look that the messages and see if there an any fixed patterns that we can represent.
# In order to make the task easier, we need to group the similar messages
# so we use clustering technique to group all the similar messages and try to find the patterns.
#
# ### RegEx Strategy

# %% [markdown]
# 1. We apply clustering we get clusters.
# 2. We find clusters with the more than 10 records.
# 3. Display 5 Samples from each clusters.
# 4. Inspect the clusters.
# 4. Create RegEx referring to the groups.

# %% [markdown]
# ### Step 1: Install and Load Sentence Transformer Library
#
# We need to install the `sentence-transformers` library to generate embeddings from text. After installation, we'll load a pre-trained model, such as `'all-MiniLM-L6-v2'`, which is a good balance of performance and speed.

# %%
# !pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.9.0+cpu)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.11.12)

# %%
from sentence_transformers import SentenceTransformer

# Load a pre-trained Sentence Transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

print("Sentence Transformer model loaded successfully.")
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Sentence Transformer model loaded successfully.

# %% [markdown]
# ### Step 2: Generate Embeddings for Log Messages
#
# Now, we'll use the loaded model to convert each `log_message` into a dense vector (embedding). These embeddings capture the semantic meaning of the messages.

# %%
print("Generating embeddings...")
# Generate embeddings for the 'log_message' column
embeddings = model.encode(df['log_message'].tolist(), show_progress_bar=True)

print(f"Embeddings generated. Shape: {embeddings.shape}")

# %%
df
# Out:
#                 timestamp           source  \
# 0     2025-06-27 07:20:25        ModernCRM
# 1         1/14/2025 23:07        ModernCRM
# 2          1/17/2025 1:29  AnalyticsEngine
# 3     2025-07-12 00:24:16         ModernHR
# 4     2025-06-02 18:25:23    BillingSystem
# ...                   ...              ...
# 2405  2025-08-13 07:29:25         ModernHR
# 2406       1/11/2025 5:32         ModernHR
# 2407  2025-08-03 03:07:47    ThirdPartyAPI
# 2408     11/11/2025 11:52    BillingSystem
# 2409     12/25/2025 13:21  AnalyticsEngine
#
#                                             log_message    target_label  \
# 0     nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1        Email service experiencing issues with sending  Critical Error
# 2             Unauthorized access to data was attempted  Security Alert
# 3     nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4     nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status
# ...                                                 ...             ...
# 2405  nova.osapi_compute.wsgi.server [req-96c3ec98-2...     HTTP Status
# 2406  User 3844 account experienced multiple failed ...  Security Alert
# 2407  nova.metadata.wsgi.server [req-b6d4a270-accb-4...     HTTP Status
# 2408      Email service affected by failed transmission  Critical Error
# 2409  Repeated failed login attempts occurred for us...  Security Alert
#
#       cluster_label
# 0                 0
# 1                 1
# 2                 2
# 3                 0
# 4                 0
# ...             ...
# 2405              0
# 2406              7
# 2407              0
# 2408              1
# 2409              7
#
# [2410 rows x 5 columns]

# %% [markdown]
# ### Step 3: Apply DBSCAN Clustering
#
# With the numerical embeddings, we can now apply DBSCAN. When working with dense embeddings, `cosine` similarity is typically a good metric. You might need to adjust `eps` and `min_samples` based on the characteristics of your dataset and desired cluster density.

# %%
from sklearn.cluster import DBSCAN


dbscan = DBSCAN(eps=0.2, min_samples=1, metric='cosine')

# Fit DBSCAN to the embeddings and get cluster labels
clusters = dbscan.fit_predict(embeddings)

# Add the cluster labels to the original DataFrame
df['cluster_label'] = clusters

print("DBSCAN clustering complete.")
# Out:
# DBSCAN clustering complete.

# %%
pd.DataFrame(clusters[:5])
# Out:
#    0
# 0  0
# 1  1
# 2  2
# 3  0
# 4  0

# %% [markdown]
# ### Step 4: Analyze the Clustering Results
#
# Let's examine the clusters found by DBSCAN. Remember that points labeled as `-1` are considered noise by the algorithm.

# %%
# Printing Cluster 1 to examine how well it was grouped.
# We find out that with the new parameters the clusters are better grouped
df[df.cluster_label==1]
# Out:
#              timestamp           source  \
# 1      1/14/2025 23:07        ModernCRM
# 10      8/9/2025 18:58        ModernCRM
# 217     1/22/2025 5:45    BillingSystem
# 248     5/2/2025 23:04         ModernHR
# 265    3/30/2025 23:53        ModernCRM
# 361   11/19/2025 23:06    BillingSystem
# 450    10/27/2025 5:59    ThirdPartyAPI
# 477    12/2/2025 10:30  AnalyticsEngine
# 570    11/7/2025 18:08    ThirdPartyAPI
# 678    4/28/2025 15:13  AnalyticsEngine
# 695    6/30/2025 12:46    ThirdPartyAPI
# 816      7/9/2025 9:38    BillingSystem
# 926     2/17/2025 8:01        ModernCRM
# 1011    2/9/2025 17:04  AnalyticsEngine
# 1018   2/16/2025 15:02    BillingSystem
# 1046  11/26/2025 22:54  AnalyticsEngine
# 1058   10/24/2025 5:37  AnalyticsEngine
# 1082   5/17/2025 11:20         ModernHR
# 1151   6/17/2025 15:13    ThirdPartyAPI
# 1176   10/1/2025 12:27  AnalyticsEngine
# 1189     2/9/2025 6:15        ModernCRM
# 1359   8/18/2025 15:58        ModernCRM
# 1414   6/22/2025 23:07        ModernCRM
# 1427  10/26/2025 20:25         ModernHR
# 1453    9/11/2025 1:18    BillingSystem
# 1554     3/2/2025 9:21        ModernCRM
# 1567   5/11/2025 11:17    ThirdPartyAPI
# 1582    9/10/2025 9:27    BillingSystem
# 1860    6/26/2025 1:08    BillingSystem
# 1867   10/6/2025 11:04        ModernCRM
# 1901    9/22/2025 2:52    ThirdPartyAPI
# 1972    3/12/2025 3:48    ThirdPartyAPI
# 2049   10/1/2025 22:07  AnalyticsEngine
# 2165    4/4/2025 16:11    ThirdPartyAPI
# 2281   3/23/2025 20:12    ThirdPartyAPI
# 2284   10/4/2025 18:15    BillingSystem
# 2312    3/9/2025 21:16         ModernHR
# 2340    3/26/2025 8:10        ModernCRM
# 2408  11/11/2025 11:52    BillingSystem
#
#                                             log_message    target_label  \
# 1        Email service experiencing issues with sending  Critical Error
# 10             Email server encountered a sending fault           Error
# 217          Mail service encountered a delivery glitch           Error
# 248    Service disruption caused by email sending error  Critical Error
# 265           Email system had a problem sending emails           Error
# 361           Email service experienced a sending issue           Error
# 450          Email delivery system encountered an error           Error
# 477      Email transmission error caused service impact  Critical Error
# 570           Email service impacted by sending failure  Critical Error
# 678              Email delivery problem affected system  Critical Error
# 695        Service outage due to email delivery problem  Critical Error
# 816            Error in email delivery affected service  Critical Error
# 926           Email service suffered a delivery failure           Error
# 1011            Error in email sending impacted service  Critical Error
# 1018           Mail service impacted by delivery glitch  Critical Error
# 1046  Email service had a difficulty delivering mess...           Error
# 1058              Email system failed to deliver emails           Error
# 1082           Delivery failure impacted email services  Critical Error
# 1151             Mail service was unable to send emails           Error
# 1176          Email provider faced a delivery challenge           Error
# 1189       Service issue caused by email delivery error  Critical Error
# 1359             Email system down due to sending error  Critical Error
# 1414           Email system encountered a sending error           Error
# 1427          Email provider had trouble sending emails           Error
# 1453         Mail delivery error impacted email service  Critical Error
# 1554     Email system had a difficulty sending messages           Error
# 1567          Email system affected by delivery failure  Critical Error
# 1582   Email delivery failure resulted in service issue  Critical Error
# 1860   Email provider experienced a mail delivery issue           Error
# 1867            Email service had a sending malfunction           Error
# 1901     Email service experienced a mail sending issue           Error
# 1972    Delivery issue with email service caused outage  Critical Error
# 2049        Email server experienced a delivery problem           Error
# 2165       Email server had trouble transmitting emails           Error
# 2281      Mail delivery issue caused service disruption  Critical Error
# 2284       Email service down due to transmission issue  Critical Error
# 2312            Email service faced a delivery obstacle           Error
# 2340     Service outage due to email transmission error  Critical Error
# 2408      Email service affected by failed transmission  Critical Error
#
#       cluster_label
# 1                 1
# 10                1
# 217               1
# 248               1
# 265               1
# 361               1
# 450               1
# 477               1
# 570               1
# 678               1
# 695               1
# 816               1
# 926               1
# 1011              1
# 1018              1
# 1046              1
# 1058              1
# 1082              1
# 1151              1
# 1176              1
# 1189              1
# 1359              1
# 1414              1
# 1427              1
# 1453              1
# 1554              1
# 1567              1
# 1582              1
# 1860              1
# 1867              1
# 1901              1
# 1972              1
# 2049              1
# 2165              1
# 2281              1
# 2284              1
# 2312              1
# 2340              1
# 2408              1

# %%
# Number of clusters found (ignoring noise points labeled as -1)
n_clusters_ = len(set(clusters)) - (1 if -1 in clusters else 0)
n_noise_ = list(clusters).count(-1)

print(f"Estimated number of clusters: {n_clusters_}")
print(f"Estimated number of noise points: {n_noise_}")

# Display the count of points per cluster
print("\nCluster distribution:")
print(df['cluster_label'].value_counts())

# Display sample log messages for a few clusters
print("\nSample log messages from different clusters:")
for cluster_id in sorted(df['cluster_label'].unique()):
    if cluster_id == -1:
        print(f"\n--- Noise Points (Cluster -1) ---")
    else:
        print(f"\n--- Cluster {cluster_id} ---")

    # Get sample messages, ensure we don't try to sample more than available
    sample_messages = df[df['cluster_label'] == cluster_id]['log_message'].sample(min(3, len(df[df['cluster_label'] == cluster_id]))).tolist()
    for msg in sample_messages:
        print(f"- {msg}")
# Out:
# Estimated number of clusters: 136
# Estimated number of noise points: 0
#
# Cluster distribution:
# cluster_label
# 0      1017
# 5       147
# 11      100
# 13       86
# 7        60
#        ...
# 131       1
# 132       1
# 133       1
# 134       1
# 135       1
# Name: count, Length: 136, dtype: int64
#
# Sample log messages from different clusters:
#
# --- Cluster 0 ---
# - nova.metadata.wsgi.server [-] 10.11.21.135,10.11.10.1 "GET /latest/meta-data/block-device-mapping/ami HTTP/1.1" Status code -  200 len: 119 time: 0.0006430
# - nova.osapi_compute.wsgi.server [req-de162460-0015-4ef5-ad34-36cdaf269be6 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" Return code: 200 len: 1893 time: 0.2570632
# - nova.metadata.wsgi.server [-] 10.11.21.140,10.11.10.1 "GET /openstack/2013-10-17/vendor_data.json HTTP/1.1" Return code: 200 len: 124 time: 0.0006189
#
# --- Cluster 1 ---
# - Delivery failure impacted email services
# - Service outage due to email transmission error
# - Email service affected by failed transmission
#
# --- Cluster 2 ---
# - Unauthorized access to data was attempted
# - Identified a possible unauthorized data access attempt
# - An unusual data access attempt was detected
#
# --- Cluster 3 ---
# - Shard 18 replication task ended in failure
# - Shard 12 data replication task was terminated
# - Shard 4 replication task ended in failure
#
# --- Cluster 4 ---
# - File data_7366.csv uploaded successfully by user User282.
# - File data_5870.csv uploaded successfully by user User443.
# - File data_2843.csv uploaded successfully by user User308.
#
# --- Cluster 5 ---
# - nova.compute.claims [req-1162e278-3bf2-4b32-93b5-9c7ec218365e 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: fecdd5a9-3ca0-4c82-9336-63b7774f738e] Attempting claim: memory 2048 MB, disk 20 GB, vcpus 1 CPU
# - nova.compute.claims [req-01d570b0-78a7-4719-b7a3-429fd7dc5a3f 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: d54b44eb-2d1a-4aa2-ba6b-074d35f8f12c] Total memory: 64172 MB, used: 512.00 MB
# - nova.compute.claims [req-9118475d-6e72-48fa-9dee-e6b7d957dcd6 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: be793e89-2cc3-4f99-9884-9c6a624a84bc] vcpu limit not specified, defaulting to unlimited
#
# --- Cluster 6 ---
# - System component is not operating: component ID Component26
# - Failure of critical system component: component ID Component92
# - Critical system unit failure: unit ID Component76
#
# --- Cluster 7 ---
# - User 2104 made multiple failed login attempts
# - User 5045 had multiple unsuccessful login attempts
# - User 8300 made multiple incorrect login attempts
#
# --- Cluster 8 ---
# - Backup completed successfully.
# - Backup completed successfully.
# - Backup completed successfully.
#
# --- Cluster 9 ---
# - Account with ID 4810 created by User581.
# - Account with ID 4585 created by User485.
# - Account with ID 6661 created by User556.
#
# --- Cluster 10 ---
# - nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Final resource view: name=cp-1.slowvm1.tcloud-pg0.utah.cloudlab.us phys_ram=64172MB used_ram=512MB phys_disk=15GB used_disk=0GB total_vcpus=16 used_vcpus=0 pci_stats=[]
# - nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Total usable vcpus: 16, total allocated vcpus: 0
# - nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Final resource view: name=cp-1.slowvm1.tcloud-pg0.utah.cloudlab.us phys_ram=64172MB used_ram=2560MB phys_disk=15GB used_disk=20GB total_vcpus=16 used_vcpus=1 pci_stats=[]
#
# --- Cluster 11 ---
# - User User838 logged out.
# - User User496 logged in.
# - User User502 logged out.
#
# --- Cluster 12 ---
# - Brute force login detected from IP 192.168.237.105 address
# - Brute force login detected from IP 192.168.246.138 address
# - Alert: brute force login attempt from 192.168.247.107 detected
#
# --- Cluster 13 ---
# - Backup ended at 2025-01-24 09:07:54.
# - Backup ended at 2025-06-26 20:07:46.
# - Backup started at 2025-10-12 10:35:15.
#
# --- Cluster 14 ---
# - Several hard drive failures in RAID system identified
# - RAID system detected multiple disk failures and errors
# - Detection of multiple failed disks in RAID setup
#
# --- Cluster 15 ---
# - Suspicious login activity detected from 192.168.72.2
# - Suspicious login activity detected from 192.168.240.157
# - Suspicious login activity detected from 192.168.24.250
#
# --- Cluster 16 ---
# - System reboot initiated by user User120.
# - System reboot initiated by user User600.
# - System reboot initiated by user User329.
#
# --- Cluster 17 ---
# - Restricted account Account9871 experienced failed login
# - Unauthorized login attempt on protected account Account2527
# - Failed login try on account Account2024 occurred
#
# --- Cluster 18 ---
# - Boot sequence failed due to kernel panic
# - Boot sequence was aborted due to kernel failure
# - System crash happened due to kernel problem during boot
#
# --- Cluster 19 ---
# - Abnormal system behavior on server 40, potential security breach
# - Abnormal system behavior on server 43, potential security breach
# - Abnormal system behavior on server 1, potential security breach
#
# --- Cluster 20 ---
# - Unapproved API login attempt from user 1618 recorded
# - Unauthorized user 8557 tried to access restricted API
# - User 4069 tried to bypass API security measures
#
# --- Cluster 21 ---
# - System updated to version 4.6.3.
# - System updated to version 2.8.3.
# - System updated to version 3.0.7.
#
# --- Cluster 22 ---
# - Server 7 restarted without warning during data migration
# - Server 46 restarted without warning during data migration
# - Server 4 restarted without warning during data migration
#
# --- Cluster 23 ---
# - Server 34 crashed unexpectedly while syncing data
# - Server 43 crashed unexpectedly while syncing data
# - Server 44 crashed unexpectedly while syncing data
#
# --- Cluster 24 ---
# - Lead conversion failed for prospect ID 7842 due to missing contact information.
#
# --- Cluster 25 ---
# - System configuration is experiencing errors
# - Configuration malfunction is system-wide
# - Cross-system configuration failure occurred
#
# --- Cluster 26 ---
# - Elevation of admin privileges detected for user 4907
# - Privilege elevation detected for user 5038
# - Elevation of admin privileges detected for user 8436
#
# --- Cluster 27 ---
# - Key system element crashed: element ID Component32
# - Key system element crashed: element ID Component77
# - Key system element crashed: element ID Component29
#
# --- Cluster 28 ---
# - Attempt to access account Account3142 was not authorized
#
# --- Cluster 29 ---
# - API intrusion detection system flagged user 6771
# - API intrusion detection system flagged user 2067
# - API intrusion detection system flagged user 2874
#
# --- Cluster 30 ---
# - Severe system crash found in core application component
# - Critical system crash occurred in core application
#
# --- Cluster 31 ---
# - Admin privilege misuse detected for user 8854
# - Detection of admin privilege misuse by user 1449
# - Detection of potential admin privilege abuse by user 2182
#
# --- Cluster 32 ---
# - Disk cleanup completed successfully.
# - Disk cleanup completed successfully.
# - Disk cleanup completed successfully.
#
# --- Cluster 33 ---
# - Server 49 is under potential security threat, review necessary
# - Server 40 is under potential security threat, review necessary
# - Server 22 is under potential security threat, review necessary
#
# --- Cluster 34 ---
# - Unidentified activity on server 47, possible security issue
# - Anomalous activity identified on server 23, security review recommended
# - Security issue detected on server 46, investigation required
#
# --- Cluster 35 ---
# - Security breach suspected from IP address 192.168.157.122
# - Security breach suspected from IP address 192.168.252.92
# - Security breach suspected from IP address 192.168.89.160
#
# --- Cluster 36 ---
# - System configuration has been tampered with
# - System configuration has been compromised entirely
#
# --- Cluster 37 ---
# - Unexpected server 11 stoppage occurred during data conversion
# - Unexpected server 41 stoppage occurred during data conversion
# - Unexpected server 46 stoppage occurred during data conversion
#
# --- Cluster 38 ---
# - API security system detected suspicious activity from user 1478
# - API security system detected suspicious activity from user 4239
# - API security system detected suspicious activity from user 9593
#
# --- Cluster 39 ---
# - Admin access escalation detected for user 8307
# - Admin access escalation detected for user 6223
# - Admin access escalation detected for user 9429
#
# --- Cluster 40 ---
# - Unrecoverable issue found in vital application module
#
# --- Cluster 41 ---
# - Server 29 is at risk due to unusual system calls, security check
# - Server 15 is at risk due to unusual system calls, security check
# - Server 30 is at risk due to unusual system calls, security check
#
# --- Cluster 42 ---
# - User 9202 has admin privileges escalated
# - User 8693 has escalated to admin level
# - User 1987 has escalated to admin level
#
# --- Cluster 43 ---
# - Non-recoverable fault detected in key application section
#
# --- Cluster 44 ---
# - Invalid credentials used for account Account4769 login
# - Invalid credentials used for account Account1056 login
# - Invalid credentials used for account Account2885 login
#
# --- Cluster 45 ---
# - Unauthorised access attempt from 192.168.99.79 detected
# - Unauthorised access attempt from 192.168.170.203 detected
# - Unusual access attempt from 192.168.197.162 logged
#
# --- Cluster 46 ---
# - Abnormal shutdown of server 6 happened during data transfer
# - Abnormal shutdown of server 13 happened during data transfer
# - Abnormal shutdown of server 1 happened during data transfer
#
# --- Cluster 47 ---
# - A data export attempt with suspicious parameters was detected
# -  Suspicious data export activity was identified
#
# --- Cluster 48 ---
# - API endpoint 'getCustomerDetails' is deprecated and will be removed in version 3.2. Use 'fetchCustomerInfo' instead.
#
# --- Cluster 49 ---
# - User 3720 has admin privileges escalated
#
# --- Cluster 50 ---
# - Server 1 underwent an unplanned restart during data download
# - Server 17 underwent an unplanned restart during data download
# - Server 31 underwent an unplanned restart during data download
#
# --- Cluster 51 ---
# - Server 6 suffered an abrupt restart during data import
# - Server 32 encountered an unforeseen restart during data processing
# - Server 34 encountered an unforeseen restart during data processing
#
# --- Cluster 52 ---
# - Service health check did not pass due to an invalid SSL certificate configuration.
# - An invalid SSL certificate prevented the service health check from passing.
# - Service health check failed to complete due to SSL certificate validation issues.
#
# --- Cluster 53 ---
# - Malformed input detected in module X
# - Invalid input syntax found in module X
# - Module X experienced an invalid data format issue
#
# --- Cluster 54 ---
# - Potential security risk from 192.168.127.20 identified
# - Potential security risk from 192.168.60.100 identified
# - Potential security risk from 192.168.81.123 identified
#
# --- Cluster 55 ---
# - An attempt to access data without clearance was made
#
# --- Cluster 56 ---
# - Unexpected termination of server 49 occurred during data update
# - Unexpected termination of server 42 occurred during data update
# - Unexpected termination of server 23 occurred during data update
#
# --- Cluster 57 ---
# - Server 18 went offline unexpectedly during data parsing
# - Server 19 went offline unexpectedly during data parsing
# - Server 28 went offline unexpectedly during data parsing
#
# --- Cluster 58 ---
# - Server 22 faced an unanticipated shutdown during data upload
# - Server 3 faced an unanticipated shutdown during data upload
# - Server 36 faced an unanticipated shutdown during data upload
#
# --- Cluster 59 ---
# - Warning: Potential admin privilege escalation for user 1559
# - Potential security threat: Admin privilege escalation for user 1554
# - Admin privilege escalation alert for user 8532
#
# --- Cluster 60 ---
# - Possible hacking attempt identified from IP 192.168.211.148
# - Possible hacking attempt identified from IP 192.168.177.239
# - Possible hacking attempt identified from IP 192.168.24.230
#
# --- Cluster 61 ---
# - Server 7 has potential security exposure, remediation needed
# - Server 10 has potential security exposure, remediation needed
#
# --- Cluster 62 ---
# - Customer follow-up process for lead ID 5621 failed due to missing next action
#
# --- Cluster 63 ---
# - IP 192.168.71.232 blocked due to potential attack
# - IP 192.168.133.114 blocked due to potential attack
# - IP 192.168.176.1 blocked due to potential attack
#
# --- Cluster 64 ---
# - Warning: IP 192.168.65.57 may be compromised
# - Warning: IP 192.168.151.28 may be compromised
# - Warning: IP 192.168.191.32 may be compromised
#
# --- Cluster 65 ---
# - Vital system component is down: component ID Component35
# - Vital system component is down: component ID Component75
# - Vital system component is down: component ID Component83
#
# --- Cluster 66 ---
# - User 2185 has gained unauthorized admin access
# - User 1988 has gained unauthorized admin access
# - UnAuthorized admin access granted to user 8267
#
# --- Cluster 67 ---
# - Critical application failure occurred in central system
# - Critical failure found in main application component
# - Fatal system failure occurred in central application
#
# --- Cluster 68 ---
# - User 4951 has been granted elevated admin privileges
#
# --- Cluster 69 ---
# - Warning: potential password cracking attempt from 192.168.228.103
# - Warning: potential password cracking attempt from 192.168.29.191
# - Warning: potential password cracking attempt from 192.168.190.64
#
# --- Cluster 70 ---
# - IP 192.168.213.121 flagged for potential security threat
# - IP 192.168.45.67 flagged for potential security threat
# - IP 192.168.139.218 flagged for potential cyber threat
#
# --- Cluster 71 ---
# - Unforeseen server 8 reboot occurred during data export
# - Unforeseen server 17 reboot occurred during data export
# - Unforeseen server 6 reboot occurred during data export
#
# --- Cluster 72 ---
# - Alert: server 31 experienced unusual login attempts, security risk
# - Alert: server 9 experienced unusual login attempts, security risk
# - Alert: server 45 experienced unusual login attempts, security risk
#
# --- Cluster 73 ---
# - Detected a potential data breach attempt
#
# --- Cluster 74 ---
# - Server 42 has potential security exposure, remediation needed
# - Potential security vulnerability found on server 42
#
# --- Cluster 75 ---
# - Potential DDoS attack from 192.168.234.122 detected
# - Potential DDoS attack from 192.168.242.180 detected
# - Potential DDoS attack from 192.168.198.240 detected
#
# --- Cluster 76 ---
# - Detected a data export attempt without authorization
# - Unauthorized data export request was intercepted
# - An attempt to export data without permission was made
#
# --- Cluster 77 ---
# - Detected an anomalous data transfer request
#
# --- Cluster 78 ---
# - Server 8 experienced an unplanned restart during data replication
# - Server 24 experienced an unplanned restart during data replication
# - Server 2 experienced an unplanned restart during data replication
#
# --- Cluster 79 ---
# - Detected an illicit data extraction attempt
# - Detected an unauthorized data extraction request
#
# --- Cluster 80 ---
# - Server 33 was rebooted without notice during data verification
# - Server 19 was rebooted without notice during data verification
# - Server 46 was rebooted without notice during data verification
#
# --- Cluster 81 ---
# - Non-recoverable error encountered in primary application
#
# --- Cluster 82 ---
# - Unanticipated server 15 restart happened during data exchange
# - Unanticipated server 3 restart happened during data exchange
# - Server 45 experienced an unanticipated restart during data reconciliation
#
# --- Cluster 83 ---
# - Unfixable issue identified in essential system module
# - Unfixable problem discovered in essential application module
#
# --- Cluster 84 ---
# - Warning: unusual patterns detected on server 25, security check advised
# - Warning: unusual patterns detected on server 5, security check advised
# - Warning: unusual patterns detected on server 2, security check advised
#
# --- Cluster 85 ---
# - Critical bug identified in main application module
#
# --- Cluster 86 ---
# - Admin privilege misuse detected for user 3117
#
# --- Cluster 87 ---
# - Possible malware activity from 192.168.71.185 detected
# - Possible malware activity from 192.168.41.4 detected
# - Possible malware activity from 192.168.33.104 detected
#
# --- Cluster 88 ---
# - Unexpected server 29 downtime occurred during data validation
# - Unexpected server 39 downtime occurred during data validation
# - Unexpected server 40 downtime occurred during data validation
#
# --- Cluster 89 ---
# - Unscheduled reboot of server 38 occurred during data synchronization
# - Unscheduled reboot of server 7 occurred during data synchronization
# - Unscheduled reboot of server 11 occurred during data synchronization
#
# --- Cluster 90 ---
# - Server 30 experienced unusual traffic, potential vulnerability
# - Server 3 experienced unusual traffic, potential vulnerability
# - Server 37 experienced unusual traffic, potential vulnerability
#
# --- Cluster 91 ---
# - Critical system issue detected in key module
#
# --- Cluster 92 ---
# - Severe error encountered in core system component
#
# --- Cluster 93 ---
# - Server 48 went down unexpectedly while data was being synced
# - Server 11 had an unexpected interruption during data synchronization
# - Server 11 went down unexpectedly while data was being synced
#
# --- Cluster 94 ---
# - Anomalous traffic from 192.168.208.255 flagged for review
# - Anomalous traffic from 192.168.210.159 flagged for review
# - Anomalous traffic from 192.168.122.215 flagged for review
#
# --- Cluster 95 ---
# - Irreparable error found in fundamental system component
#
# --- Cluster 96 ---
# - Server 26 shows signs of unauthorized access, security risk present
# - Server 13 shows signs of unauthorized access, security risk present
#
# --- Cluster 97 ---
# - Detected an unauthorized attempt to transfer data
# - Unauthenticated data transfer attempt was detected
# - Detected a data transfer attempt with insufficient credentials
#
# --- Cluster 98 ---
# - IP 192.168.183.14 identified as potential attack source
# - IP 192.168.11.74 identified as potential attack source
# - IP 192.168.144.128 identified as potential attack source
#
# --- Cluster 99 ---
# - User 3080 has been granted elevated admin privileges
#
# --- Cluster 100 ---
# - Mail server faced a transmission problem
#
# --- Cluster 101 ---
# - Security warning: unusual network activity on server 41
# - Security warning: unusual network activity on server 7
# - Security warning: unusual network activity on server 42
#
# --- Cluster 102 ---
# - Configuration integrity is at risk system-wide
#
# --- Cluster 103 ---
# - Attempt to access account Account5260 was not authorized
#
# --- Cluster 104 ---
# - Critical system device issue: device ID Component20
# - Critical system device issue: device ID Component52
# - Critical system device issue: device ID Component18
#
# --- Cluster 105 ---
# - Escalation rule execution failed for ticket ID 9807 - undefined escalation level.
#
# --- Cluster 106 ---
# - Server 9 encountered an unforeseen restart during data processing
#
# --- Cluster 107 ---
# - Security alert: suspicious activity from 192.168.214.63
# - Security alert: suspicious activity from 192.168.23.39
# - Security alert: suspicious activity from 192.168.140.76
#
# --- Cluster 108 ---
# - Severe application issue found in main system component
#
# --- Cluster 109 ---
# - Data export attempt exceeded authorized limits
#
# --- Cluster 110 ---
# - Server 4 has been compromised, potential security risk
#
# --- Cluster 111 ---
# - Widespread configuration damage has been found
#
# --- Cluster 112 ---
# - Account Account3011 blocked due to failed login
#
# --- Cluster 113 ---
# - Unsanctioned data transfer request was received
#
# --- Cluster 114 ---
# - Account Account5342 access denied due to login failure
#
# --- Cluster 115 ---
# - Operating system failed to boot properly
#
# --- Cluster 116 ---
# - System crash occurred during operating system startup
# - System crash happened during startup process
#
# --- Cluster 117 ---
# - Potential vulnerability exploit detected from 192.168.152.25
# - Potential vulnerability exploit detected from 192.168.52.4
# - Potential vulnerability exploit detected from 192.168.96.60
#
# --- Cluster 118 ---
# - The 'ExportToCSV' feature is outdated. Please migrate to 'ExportToXLSX' by the end of Q3.
#
# --- Cluster 119 ---
# - Potential security vulnerability found on server 6
#
# --- Cluster 120 ---
# - Terminal system failure encountered in crucial module
# - Terminal failure detected in crucial application section
#
# --- Cluster 121 ---
# - Server 45 shows signs of unauthorized access, security risk present
#
# --- Cluster 122 ---
# - Support for legacy authentication methods will be discontinued after 2025-06-01.
#
# --- Cluster 123 ---
# - Systemic configuration issue has been detected
# - Systemic configuration inconsistencies detected
#
# --- Cluster 124 ---
# - Attempt to access account Account1376 was not authorized
#
# --- Cluster 125 ---
# - Fatal issue encountered in central system module
#
# --- Cluster 126 ---
# - Severe malfunction identified in primary software module
#
# --- Cluster 127 ---
# - Potential security vulnerability found on server 29
#
# --- Cluster 128 ---
# - User 1809 has escalated admin privileges without authorization
#
# --- Cluster 129 ---
# - Server 20 has been flagged for suspicious activity, security review
#
# --- Cluster 130 ---
# - Irreparable failure detected in fundamental application
#
# --- Cluster 131 ---
# - Global settings have been compromised
#
# --- Cluster 132 ---
# - Admin rights elevated for user 1776
#
# --- Cluster 133 ---
# - Task assignment for TeamID 3425 could not complete due to invalid priority level.
#
# --- Cluster 134 ---
# - System configuration inconsistencies were found
#
# --- Cluster 135 ---
# - Admin rights elevated for user 3310

# %%
df[df.cluster_label==5]
# Out:
#                 timestamp           source  \
# 8     2025-02-12 10:42:29    ThirdPartyAPI
# 26    2025-03-03 17:11:11        ModernCRM
# 40    2025-06-19 21:42:34    ThirdPartyAPI
# 58    2025-09-13 14:45:14  AnalyticsEngine
# 61    2025-04-27 11:18:18    ThirdPartyAPI
# ...                   ...              ...
# 2336  2025-12-10 11:53:33  AnalyticsEngine
# 2345  2025-12-22 01:38:48    BillingSystem
# 2352  2025-02-18 00:16:44        ModernCRM
# 2355  2025-11-28 18:03:55    BillingSystem
# 2372  2025-08-07 05:49:03    ThirdPartyAPI
#
#                                             log_message    target_label  \
# 8     nova.compute.claims [req-a07ac654-8e81-416d-bf...  Resource Usage
# 26    nova.compute.claims [req-d6986b54-3735-4a42-90...  Resource Usage
# 40    nova.compute.claims [req-72b4858f-049e-49e1-b3...  Resource Usage
# 58    nova.compute.claims [req-5c8f52bd-8e3c-41f0-95...  Resource Usage
# 61    nova.compute.claims [req-d38f479d-9bb9-4276-96...  Resource Usage
# ...                                                 ...             ...
# 2336  nova.compute.claims [req-97fcea79-42f7-4241-9b...  Resource Usage
# 2345  nova.compute.claims [req-caeb3818-dab6-4e8d-9e...  Resource Usage
# 2352  nova.compute.claims [req-98474cd9-61e1-4afe-bd...  Resource Usage
# 2355  nova.compute.claims [req-6f9ecdfe-481c-4535-9b...  Resource Usage
# 2372  nova.compute.claims [req-01d570b0-78a7-4719-b7...  Resource Usage
#
#      complexity  cluster_label
# 8          bert              5
# 26         bert              5
# 40         bert              5
# 58         bert              5
# 61         bert              5
# ...         ...            ...
# 2336       bert              5
# 2345       bert              5
# 2352       bert              5
# 2355       bert              5
# 2372       bert              5
#
# [147 rows x 6 columns]

# %% [markdown]
# **Reasoning**:
# To identify large clusters, I will count the occurrences of each 'cluster_label' in the DataFrame and then filter these counts to include only clusters with more than 10 records, storing the result in `large_clusters`.

# %%
cluster_counts = df['cluster_label'].value_counts()
large_clusters = cluster_counts[cluster_counts > 10]

print("Clusters with more than 10 records:")
print(large_clusters)
# Out:
# Clusters with more than 10 records:
# cluster_label
# 0     1017
# 5      147
# 11     100
# 13      86
# 7       60
# 8       60
# 21      58
# 3       57
# 4       53
# 17      52
# 6       51
# 32      51
# 16      48
# 20      48
# 9       44
# 1       39
# 10      30
# 34      25
# 53      20
# 14      20
# 52      20
# 18      17
# 42      13
# 25      13
# 59      12
# 26      11
# Name: count, dtype: int64

# %% [markdown]
# **Reasoning**:
# Now that the large clusters have been identified, the next step is to iterate through each of these large clusters and display up to 5 sample log messages from each to provide insights into their content.

# %%
print("\nSummarizing large clusters and providing sample log messages:")

for cluster_id in large_clusters.index:
    print(f"\n--- Cluster {cluster_id} (Count: {large_clusters[cluster_id]}) ---")

    # Get sample messages, ensuring not to try and sample more than available
    sample_df = df[df['cluster_label'] == cluster_id][['log_message', 'target_label']].sample(min(5, large_clusters[cluster_id]))
    for _, row in sample_df.iterrows():
        print(f"- Log Message: {row['log_message']}\n  Target Label: {row['target_label']}")
# Out:
# Summarizing large clusters and providing sample log messages:
#
# --- Cluster 0 (Count: 1017) ---
# - Log Message: nova.metadata.wsgi.server [-] 10.11.21.124,10.11.10.1 "GET /openstack/2013-10-17/vendor_data.json HTTP/1.1" RCODE  200 len: 124 time: 0.0006270
#   Target Label: HTTP Status
# - Log Message: nova.osapi_compute.wsgi.server [req-c4d0c20c-cfe8-4e66-b280-b083419d4967 f7b8d1f1d4d44643b07fa10ca7d021fb e9746973ac574c6b8a9e8857f56a7608 - - -] 10.11.10.1 "POST /v2/e9746973ac574c6b8a9e8857f56a7608/os-server-external-events HTTP/1.1" HTTP status code -  404 len: 296 time: 0.0833371
#   Target Label: HTTP Status
# - Log Message: nova.osapi_compute.wsgi.server [req-95aa6171-064c-4a8f-96f6-d43250af4408 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" Status code -  200 len: 1893 time: 0.2598760
#   Target Label: HTTP Status
# - Log Message: nova.metadata.wsgi.server [-] 10.11.21.139,10.11.10.1 "GET /latest/meta-data/placement/availability-zone HTTP/1.1" RCODE  200 len: 120 time: 0.0008299
#   Target Label: HTTP Status
# - Log Message: nova.osapi_compute.wsgi.server [req-6d8d14b0-9baf-4de0-b02a-abd9d158342d 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" Return code: 200 len: 1893 time: 0.2724118
#   Target Label: HTTP Status
#
# --- Cluster 5 (Count: 147) ---
# - Log Message: nova.compute.claims [req-d82fab16-60f8-4c9f-bde8-f362f57bdd40 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: ae3a1b5d-eec1-45bb-b76a-c59d83b1471f] Total memory: 64172 MB, used: 512.00 MB
#   Target Label: Resource Usage
# - Log Message: nova.compute.claims [req-d38f479d-9bb9-4276-9688-52607e8fd350 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: 95960536-049b-41f6-9049-05fc479b6a7c] disk limit not specified, defaulting to unlimited
#   Target Label: Resource Usage
# - Log Message: nova.compute.claims [req-72b4858f-049e-49e1-b31e-b562c5018eaf 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: 63a0d960-70b6-44c6-b606-491478a5cadf] Total memory: 64172 MB, used: 512.00 MB
#   Target Label: Resource Usage
# - Log Message: nova.compute.claims [req-a07ac654-8e81-416d-bfbb-189116b07969 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: bf8c824d-f099-4433-a41e-e3da7578262e] disk limit not specified, defaulting to unlimited
#   Target Label: Resource Usage
# - Log Message: nova.compute.claims [req-beb938db-df6e-4611-8113-1a148a0224bc 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: d6b7bd36-2943-4363-9235-fffdd89ea40e] Total memory: 64172 MB, used: 512.00 MB
#   Target Label: Resource Usage
#
# --- Cluster 11 (Count: 100) ---
# - Log Message: User User640 logged out.
#   Target Label: User Action
# - Log Message: User User541 logged in.
#   Target Label: User Action
# - Log Message: User User231 logged out.
#   Target Label: User Action
# - Log Message: User User225 logged in.
#   Target Label: User Action
# - Log Message: User User395 logged in.
#   Target Label: User Action
#
# --- Cluster 13 (Count: 86) ---
# - Log Message: Backup ended at 2025-08-22 07:33:55.
#   Target Label: System Notification
# - Log Message: Backup ended at 2025-11-16 08:17:13.
#   Target Label: System Notification
# - Log Message: Backup ended at 2025-03-12 11:19:02.
#   Target Label: System Notification
# - Log Message: Backup started at 2025-03-12 22:42:26.
#   Target Label: System Notification
# - Log Message: Backup ended at 2025-04-28 17:49:19.
#   Target Label: System Notification
#
# --- Cluster 7 (Count: 60) ---
# - Log Message: User 7153 made multiple incorrect login attempts
#   Target Label: Security Alert
# - Log Message: Multiple login failures occurred on user 6454 account
#   Target Label: Security Alert
# - Log Message: User 3692 account had multiple failed login tries
#   Target Label: Security Alert
# - Log Message: Multiple incorrect login attempts were made by user 7798
#   Target Label: Security Alert
# - Log Message: Multiple rejected login attempts found for user 1270
#   Target Label: Security Alert
#
# --- Cluster 8 (Count: 60) ---
# - Log Message: Backup completed successfully.
#   Target Label: System Notification
# - Log Message: Backup completed successfully.
#   Target Label: System Notification
# - Log Message: Backup completed successfully.
#   Target Label: System Notification
# - Log Message: Backup completed successfully.
#   Target Label: System Notification
# - Log Message: Backup completed successfully.
#   Target Label: System Notification
#
# --- Cluster 21 (Count: 58) ---
# - Log Message: System updated to version 5.0.9.
#   Target Label: System Notification
# - Log Message: System updated to version 4.4.0.
#   Target Label: System Notification
# - Log Message: System updated to version 5.8.1.
#   Target Label: System Notification
# - Log Message: System updated to version 5.8.4.
#   Target Label: System Notification
# - Log Message: System updated to version 2.4.4.
#   Target Label: System Notification
#
# --- Cluster 3 (Count: 57) ---
# - Log Message: Data replication task failed for shard 1
#   Target Label: Error
# - Log Message: Data replication for shard 2 was unsuccessful
#   Target Label: Error
# - Log Message: Shard 11 data replication task was terminated
#   Target Label: Error
# - Log Message: Shard 18 data transfer failed
#   Target Label: Error
# - Log Message: Shard 8 synchronization task failed
#   Target Label: Error
#
# --- Cluster 4 (Count: 53) ---
# - Log Message: File data_8212.csv uploaded successfully by user User846.
#   Target Label: System Notification
# - Log Message: File data_2777.csv uploaded successfully by user User629.
#   Target Label: System Notification
# - Log Message: File data_8435.csv uploaded successfully by user User424.
#   Target Label: System Notification
# - Log Message: File data_4497.csv uploaded successfully by user User379.
#   Target Label: System Notification
# - Log Message: File data_7366.csv uploaded successfully by user User282.
#   Target Label: System Notification
#
# --- Cluster 17 (Count: 52) ---
# - Log Message: Login to secured account Account6057 was not possible
#   Target Label: Security Alert
# - Log Message: Account Account2345 experienced unauthorized login attempt
#   Target Label: Security Alert
# - Log Message: Failed access attempt on limited account Account4615
#   Target Label: Security Alert
# - Log Message: Invalid login attempt made on secured account Account9649
#   Target Label: Security Alert
# - Log Message: Secured account Account8925 had unsuccessful login attempt
#   Target Label: Security Alert
#
# --- Cluster 6 (Count: 51) ---
# - Log Message: Failure occurred in critical system component: component ID Component92
#   Target Label: Critical Error
# - Log Message: System component is not operating: component ID Component26
#   Target Label: Critical Error
# - Log Message: Essential system part malfunction: part ID Component54
#   Target Label: Critical Error
# - Log Message: Essential system part malfunction: part ID Component6
#   Target Label: Critical Error
# - Log Message: System component failure occurred: component ID Component54
#   Target Label: Critical Error
#
# --- Cluster 32 (Count: 51) ---
# - Log Message: Disk cleanup completed successfully.
#   Target Label: System Notification
# - Log Message: Disk cleanup completed successfully.
#   Target Label: System Notification
# - Log Message: Disk cleanup completed successfully.
#   Target Label: System Notification
# - Log Message: Disk cleanup completed successfully.
#   Target Label: System Notification
# - Log Message: Disk cleanup completed successfully.
#   Target Label: System Notification
#
# --- Cluster 16 (Count: 48) ---
# - Log Message: System reboot initiated by user User179.
#   Target Label: System Notification
# - Log Message: System reboot initiated by user User488.
#   Target Label: System Notification
# - Log Message: System reboot initiated by user User899.
#   Target Label: System Notification
# - Log Message: System reboot initiated by user User155.
#   Target Label: System Notification
# - Log Message: System reboot initiated by user User901.
#   Target Label: System Notification
#
# --- Cluster 20 (Count: 48) ---
# - Log Message: API access log shows unauthorized attempt by user 9193
#   Target Label: Security Alert
# - Log Message: API access log shows unauthorized attempt by user 5643
#   Target Label: Security Alert
# - Log Message: User 3490 failed to provide valid API access credentials
#   Target Label: Security Alert
# - Log Message: Unauthorized user 8557 tried to access restricted API
#   Target Label: Security Alert
# - Log Message: Unauthenticated API access attempt from user 7672 logged
#   Target Label: Security Alert
#
# --- Cluster 9 (Count: 44) ---
# - Log Message: Account with ID 6616 created by User170.
#   Target Label: User Action
# - Log Message: Account with ID 1478 created by User605.
#   Target Label: User Action
# - Log Message: Account with ID 6661 created by User556.
#   Target Label: User Action
# - Log Message: Account with ID 9614 created by User610.
#   Target Label: User Action
# - Log Message: Account with ID 9621 created by User886.
#   Target Label: User Action
#
# --- Cluster 1 (Count: 39) ---
# - Log Message: Delivery failure impacted email services
#   Target Label: Critical Error
# - Log Message: Mail delivery issue caused service disruption
#   Target Label: Critical Error
# - Log Message: Error in email delivery affected service
#   Target Label: Critical Error
# - Log Message: Email service experiencing issues with sending
#   Target Label: Critical Error
# - Log Message: Email service experienced a sending issue
#   Target Label: Error
#
# --- Cluster 10 (Count: 30) ---
# - Log Message: nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Total usable vcpus: 16, total allocated vcpus: 1
#   Target Label: Resource Usage
# - Log Message: nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Final resource view: name=cp-1.slowvm1.tcloud-pg0.utah.cloudlab.us phys_ram=64172MB used_ram=512MB phys_disk=15GB used_disk=0GB total_vcpus=16 used_vcpus=0 pci_stats=[]
#   Target Label: Resource Usage
# - Log Message: nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Total usable vcpus: 16, total allocated vcpus: 0
#   Target Label: Resource Usage
# - Log Message: nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Final resource view: name=cp-1.slowvm1.tcloud-pg0.utah.cloudlab.us phys_ram=64172MB used_ram=2560MB phys_disk=15GB used_disk=20GB total_vcpus=16 used_vcpus=1 pci_stats=[]
#   Target Label: Resource Usage
# - Log Message: nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Final resource view: name=cp-1.slowvm1.tcloud-pg0.utah.cloudlab.us phys_ram=64172MB used_ram=512MB phys_disk=15GB used_disk=0GB total_vcpus=16 used_vcpus=0 pci_stats=[]
#   Target Label: Resource Usage
#
# --- Cluster 34 (Count: 25) ---
# - Log Message: Server 27 experienced potential security incident, review required
#   Target Label: Security Alert
# - Log Message: Anomalous activity identified on server 47, security review recommended
#   Target Label: Security Alert
# - Log Message: Server 36 experienced potential security incident, review required
#   Target Label: Security Alert
# - Log Message: Security issue detected on server 43, investigation required
#   Target Label: Security Alert
# - Log Message: Security issue detected on server 23, investigation required
#   Target Label: Security Alert
#
# --- Cluster 53 (Count: 20) ---
# - Log Message: Input to module X was not in the expected format
#   Target Label: Error
# - Log Message: Module X was unable to parse input due to format error
#   Target Label: Error
# - Log Message: Invalid input syntax found in module X
#   Target Label: Error
# - Log Message: Invalid data encountered during execution of module X
#   Target Label: Error
# - Log Message: Error in input format occurred during module X execution
#   Target Label: Error
#
# --- Cluster 14 (Count: 20) ---
# - Log Message: Detection of multiple disk faults in RAID setup
#   Target Label: Critical Error
# - Log Message: Multiple disk malfunctions in RAID setup identified
#   Target Label: Critical Error
# - Log Message: RAID system detected multiple disk failures and errors
#   Target Label: Critical Error
# - Log Message: Multiple disk errors in RAID system detected and reported
#   Target Label: Critical Error
# - Log Message: Several hard drive failures in RAID system identified
#   Target Label: Critical Error
#
# --- Cluster 52 (Count: 20) ---
# - Log Message: SSL certificate errors led to a failed service health check.
#   Target Label: Error
# - Log Message: Service health check did not pass due to an invalid SSL certificate configuration.
#   Target Label: Error
# - Log Message: The service health check could not complete due to an SSL certificate issue.
#   Target Label: Error
# - Log Message: Service health check failed because of an invalid SSL certificate.
#   Target Label: Error
# - Log Message: Service health check was not successful because of SSL certificate validation failures.
#   Target Label: Error
#
# --- Cluster 18 (Count: 17) ---
# - Log Message: Boot sequence was aborted due to kernel failure
#   Target Label: Critical Error
# - Log Message: Kernel error terminated boot process prematurely
#   Target Label: Critical Error
# - Log Message: Kernel problem caused system to crash during boot
#   Target Label: Critical Error
# - Log Message: Boot process was interrupted by kernel error
#   Target Label: Critical Error
# - Log Message: System encountered kernel failure during bootup sequence
#   Target Label: Critical Error
#
# --- Cluster 42 (Count: 13) ---
# - Log Message: User 9745 has escalated to admin level
#   Target Label: Security Alert
# - Log Message: User 8693 has escalated to admin level
#   Target Label: Security Alert
# - Log Message: User 5127 has escalated admin privileges without authorization
#   Target Label: Security Alert
# - Log Message: User 9202 has admin privileges escalated
#   Target Label: Security Alert
# - Log Message: User 3098 escalated privileges to admin level
#   Target Label: Security Alert
#
# --- Cluster 25 (Count: 13) ---
# - Log Message: System configuration errors have been detected
#   Target Label: Critical Error
# - Log Message: Cross-system configuration failure occurred
#   Target Label: Critical Error
# - Log Message: System configuration is experiencing errors
#   Target Label: Critical Error
# - Log Message: Configuration errors were found system-wide
#   Target Label: Critical Error
# - Log Message: System configuration is no longer valid
#   Target Label: Critical Error
#
# --- Cluster 59 (Count: 12) ---
# - Log Message: Potential security threat: Admin privilege escalation for user 5130
#   Target Label: Security Alert
# - Log Message: Alert: Admin privilege escalation for user 9724 detected
#   Target Label: Security Alert
# - Log Message: Potential security threat: Admin privilege escalation for user 5550
#   Target Label: Security Alert
# - Log Message: Admin privilege escalation alert for user 2893
#   Target Label: Security Alert
# - Log Message: Admin privilege escalation alert for user 2655
#   Target Label: Security Alert
#
# --- Cluster 26 (Count: 11) ---
# - Log Message: Privilege elevation detected for user 6942
#   Target Label: Security Alert
# - Log Message: Privilege elevation detected for user 5038
#   Target Label: Security Alert
# - Log Message: Elevation of admin privileges detected for user 6137
#   Target Label: Security Alert
# - Log Message: Elevation of admin privileges detected for user 8436
#   Target Label: Security Alert
# - Log Message: Admin privilege elevation warning for user 8383
#   Target Label: Security Alert

# %% [markdown]
# ### Regex Classification

# %%
import re
def classify_with_regex(log_message):
  regex_patterns = {
    # HTTP Status (Cluster 0)
    r"nova\.(metadata|osapi_compute)\.wsgi\.server .* (RCODE|HTTP status code -|Status code -|Return code:)  ?\d{3} len: \d+ time: .*": "HTTP Status",

    # Resource Usage (Clusters 5, 10)
    r"nova\.compute\.(claims|resource_tracker) .* (Total memory|disk limit|Total usable vcpus|Final resource view): .*": "Resource Usage",

    # User Action (Clusters 11, 9)
    r"User User\d+ logged (in|out)\.": "User Action",
    r"Account with ID .* created by .*.": "User Action",

    # System Notification (Clusters 13, 8, 21, 4, 32, 16)
    r"Backup (started|ended) at .*": "System Notification",
    r"Backup completed successfully.*": "System Notification",
    r"System updated to version \d+\.\d+\.\d+\.": "System Notification",
    r"File .* uploaded successfully by user User\d+\.": "System Notification",
    r"Disk cleanup completed successfully\.": "System Notification",
    r"System reboot initiated by user User\d+\.": "System Notification",

    # Security Alert (Clusters 7, 17, 20, 34, 42, 59, 26)
    r".*(incorrect|failed|rejected) login attempts?.*user \d+.*": "Security Alert",
    r".*(Account\d+|secured account).* (unauthorized|unsuccessful|failed|not possible) (login|access).*": "Security Alert",
    r".*(unauthorized|unauthenticated) API access attempt.*user \d+.*": "Security Alert",
    r"Server \d+ experienced potential security incident.*": "Security Alert",
    r"Anomalous activity identified on server \d+.*": "Security Alert",
    r"User \d+ (has )?(escalated|elevated).*admin.*": "Security Alert",
    r".*Admin privilege escalation (alert|threat) for user \d+.*": "Security Alert",

    # Critical Error (Clusters 6, 14, 18, 25, 1)
    r".*(Failure|malfunction|not operating).*component ID Component\d+.*": "Critical Error",
    r".*(RAID|disk).* (faults|malfunctions|failures|errors).*": "Critical Error",
    r"(Boot|Kernel) .* (aborted|failure|terminated|crash|interrupted).*": "Critical Error",
    r"System configuration (errors|failure).*": "Critical Error",
    r"(Delivery failure|Mail delivery issue).*email services": "Critical Error",

    # Error (Clusters 3, 53, 52, 1)
    r"(Data replication|Shard \d+) .* (failed|unsuccessful|terminated)": "Error",
    r".*module X.*(parse|format|syntax|Invalid).*": "Error",
    r"Service health check .* (SSL certificate|invalid|failed).*": "Error",
    r"Email service experiencing issues.*": "Error"
    }
  for pattern, label in regex_patterns.items():
    if re.search(pattern, log_message, re.IGNORECASE):
      return label
  return None

# %%
classify_with_regex("backup completed successfully.")
# Out:
# 'System Notification'

# %% [markdown]
# ### Applying Regex Classification
#
# 1. We apply regex classification to all the data.
# 2. Do do that by applying a classify_with_regex function.
# 3. This function takes in each cell inside the log_message.
# 4. That classification function compares the log_message using re module
# 5. The search method from re module re.search(pattern, log_message).

# %%
df['regex_label'] = df['log_message'].apply(classify_with_regex)

# %%
df
# Out:
#                 timestamp           source  \
# 0     2025-06-27 07:20:25        ModernCRM
# 1         1/14/2025 23:07        ModernCRM
# 2          1/17/2025 1:29  AnalyticsEngine
# 3     2025-07-12 00:24:16         ModernHR
# 4     2025-06-02 18:25:23    BillingSystem
# ...                   ...              ...
# 2405  2025-08-13 07:29:25         ModernHR
# 2406       1/11/2025 5:32         ModernHR
# 2407  2025-08-03 03:07:47    ThirdPartyAPI
# 2408     11/11/2025 11:52    BillingSystem
# 2409     12/25/2025 13:21  AnalyticsEngine
#
#                                             log_message    target_label  \
# 0     nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1        Email service experiencing issues with sending  Critical Error
# 2             Unauthorized access to data was attempted  Security Alert
# 3     nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4     nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status
# ...                                                 ...             ...
# 2405  nova.osapi_compute.wsgi.server [req-96c3ec98-2...     HTTP Status
# 2406  User 3844 account experienced multiple failed ...  Security Alert
# 2407  nova.metadata.wsgi.server [req-b6d4a270-accb-4...     HTTP Status
# 2408      Email service affected by failed transmission  Critical Error
# 2409  Repeated failed login attempts occurred for us...  Security Alert
#
#       cluster_label  regex_label
# 0                 0         None
# 1                 1        Error
# 2                 2         None
# 3                 0  HTTP Status
# 4                 0  HTTP Status
# ...             ...          ...
# 2405              0  HTTP Status
# 2406              7         None
# 2407              0  HTTP Status
# 2408              1         None
# 2409              7         None
#
# [2410 rows x 6 columns]

# %% [markdown]
# ### See which rows it assigned the label

# %%
classified_df = df[df.regex_label.notnull()]

# %%
print("Number of Classification done by RegEx: ", classified_df.shape)
print("Number of Classifications that could not be done by RegEx", df.shape)
# Out:
# Number of Classification done by ReGex:  (1492, 6)
# Number of Classifications that could not be done by ReGex (2410, 6)

# %%
classified_df
# Out:
#                 timestamp         source  \
# 1         1/14/2025 23:07      ModernCRM
# 3     2025-07-12 00:24:16       ModernHR
# 4     2025-06-02 18:25:23  BillingSystem
# 5     2025-10-09 10:30:31       ModernHR
# 7         10/11/2025 8:44       ModernHR
# ...                   ...            ...
# 2400  2025-01-07 09:13:28  ThirdPartyAPI
# 2403       10/1/2025 1:31      ModernCRM
# 2404  2025-09-18 02:18:30  ThirdPartyAPI
# 2405  2025-08-13 07:29:25       ModernHR
# 2407  2025-08-03 03:07:47  ThirdPartyAPI
#
#                                             log_message         target_label  \
# 1        Email service experiencing issues with sending       Critical Error
# 3     nova.osapi_compute.wsgi.server [req-4895c258-b...          HTTP Status
# 4     nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...          HTTP Status
# 5     nova.osapi_compute.wsgi.server [req-f0bffbc3-5...          HTTP Status
# 7     File data_6169.csv uploaded successfully by us...  System Notification
# ...                                                 ...                  ...
# 2400  nova.compute.resource_tracker [req-addc1839-2e...       Resource Usage
# 2403                     Backup completed successfully.  System Notification
# 2404  nova.osapi_compute.wsgi.server [req-2c9c783f-3...          HTTP Status
# 2405  nova.osapi_compute.wsgi.server [req-96c3ec98-2...          HTTP Status
# 2407  nova.metadata.wsgi.server [req-b6d4a270-accb-4...          HTTP Status
#
#       cluster_label          regex_label
# 1                 1                Error
# 3                 0          HTTP Status
# 4                 0          HTTP Status
# 5                 0          HTTP Status
# 7                 4  System Notification
# ...             ...                  ...
# 2400             10       Resource Usage
# 2403              8  System Notification
# 2404              0          HTTP Status
# 2405              0          HTTP Status
# 2407              0          HTTP Status
#
# [1492 rows x 6 columns]

# %% [markdown]
# ### Evaluation of the RegEx classification
#
# Perceision: Percision measures "correct prediction of a class/ it was false but you labeled it as true"
#
# Recall : Recal measures "correct prediction of a class/ it was true but you labeled it as false "

# %%
from sklearn.metrics import precision_score, recall_score, classification_report

# Assuming 'target_label' is the true label and 'regex_label' is the predicted label
y_true = classified_df['target_label']
y_pred = classified_df['regex_label']

# Calculate Precision (using 'weighted' average for multi-class classification)
precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)

# Calculate Recall (using 'weighted' average for multi-class classification)
recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")

# Generate a classification report for a more detailed breakdown
print("\nClassification Report:")
print(classification_report(y_true, y_pred, zero_division=0))
# Out:
# Precision: 0.9993
# Recall: 0.9993
#
# Classification Report:
#                      precision    recall  f1-score   support
#
#      Critical Error       1.00      0.97      0.99        34
#               Error       0.98      1.00      0.99        44
#         HTTP Status       1.00      1.00      1.00       818
#      Resource Usage       1.00      1.00      1.00        51
#      Security Alert       1.00      1.00      1.00        45
# System Notification       1.00      1.00      1.00       356
#         User Action       1.00      1.00      1.00       144
#
#            accuracy                           1.00      1492
#           macro avg       1.00      1.00      1.00      1492
#        weighted avg       1.00      1.00      1.00      1492

# %% [markdown]
# ### Percentage of Classfication done by RegEx

# %%
print("Percentage of Classfication handled by RegEx", (classified_df.shape[0]/df.shape[0])*100, "%")
# Out:
# Percentage of Classfication handled by RegEx 61.90871369294606 %

# %% [markdown]
# ### Bert + Logistic Regression
# SUMMARY
# 1. We create a new dataset where the values were Null
# 2. We get a complete new data frame
# 3. We try to see which target labels have a fewest examples so were conducting EDA again.
# 4. It turns out to be Deprecation Warning and Workflow Error
# 5. We create a new dataset without those target labels
# 6. Train Logistic Regression Model
# 7. Save the model using JobLib

# %%
df_non_regex = df[df['regex_label'].isnull()].copy()
df_non_regex
# Out:
#                 timestamp           source  \
# 0     2025-06-27 07:20:25        ModernCRM
# 2          1/17/2025 1:29  AnalyticsEngine
# 6          3/1/2025 19:14         ModernHR
# 10         8/9/2025 18:58        ModernCRM
# 11        6/15/2025 11:44         ModernHR
# ...                   ...              ...
# 2401  2025-12-05 15:51:51        ModernCRM
# 2402       3/13/2025 9:44    BillingSystem
# 2406       1/11/2025 5:32         ModernHR
# 2408     11/11/2025 11:52    BillingSystem
# 2409     12/25/2025 13:21  AnalyticsEngine
#
#                                             log_message    target_label  \
# 0     nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 2             Unauthorized access to data was attempted  Security Alert
# 6             Shard 6 replication task ended in failure           Error
# 10             Email server encountered a sending fault           Error
# 11      Critical system unit error: unit ID Component55  Critical Error
# ...                                                 ...             ...
# 2401  nova.osapi_compute.wsgi.server [req-4bdf00b0-3...     HTTP Status
# 2402            Replication error occurred for shard 10           Error
# 2406  User 3844 account experienced multiple failed ...  Security Alert
# 2408      Email service affected by failed transmission  Critical Error
# 2409  Repeated failed login attempts occurred for us...  Security Alert
#
#       cluster_label regex_label
# 0                 0        None
# 2                 2        None
# 6                 3        None
# 10                1        None
# 11                6        None
# ...             ...         ...
# 2401              0        None
# 2402              3        None
# 2406              7        None
# 2408              1        None
# 2409              7        None
#
# [918 rows x 6 columns]

# %% [markdown]
# ### How do we know if there are enough training samples or not?
# 1. Do it programatically, by looking at the target labels
# 2. Talk to business managers or seniors

# %%
label_counts_non_regex = df_non_regex['target_label'].value_counts()
low_frequency_labels = label_counts_non_regex[label_counts_non_regex <= 5]

print("Target Labels with 5 or fewer rows in df_non_regex:")
print(low_frequency_labels)
# Out:
# Target Labels with 5 or fewer rows in df_non_regex:
# target_label
# Workflow Error         4
# Deprecation Warning    3
# Name: count, dtype: int64

# %% [markdown]
# ### Lets start bert based

# %%
df_non_legacy = df_non_regex[df_non_regex.source != 'LegacyCRM'] # LegacyCRM because it maps to Deprecation Warning and Wrokflow error, so we take those target labels out

df_non_legacy.source.unique()
# Out:
# array(['ModernCRM', 'AnalyticsEngine', 'ModernHR', 'ThirdPartyAPI',
#        'BillingSystem'], dtype=object)

# %%
filtered_embeddings = model.encode(df_non_legacy['log_message'].tolist())
filtered_embeddings[:2]
# Out:
# array([[-1.02939598e-01,  3.35459486e-02, -2.20260844e-02,
#          1.55103172e-03, -9.86921880e-03, -1.78956211e-01,
#         -6.34409934e-02, -6.01761453e-02,  2.81108953e-02,
#          5.99620081e-02, -1.72618236e-02,  1.43364200e-03,
#         -1.49560079e-01,  3.15288268e-03, -5.66030741e-02,
#          2.71685328e-02, -1.49890278e-02, -3.54037210e-02,
#         -3.62936370e-02, -1.45410486e-02, -5.61492983e-03,
#          8.75538811e-02,  4.55120727e-02,  2.50963680e-02,
#          1.00187613e-02,  1.24267004e-02, -1.39923558e-01,
#          7.68696666e-02,  3.14095393e-02, -4.15247958e-03,
#          4.36902344e-02,  1.71249956e-02, -8.00950900e-02,
#          5.74006140e-02,  1.89092122e-02,  8.55262056e-02,
#          3.96399088e-02, -1.34371832e-01, -1.44367013e-03,
#          3.06707830e-03,  1.76854059e-01,  4.44890792e-03,
#         -1.69275142e-02,  2.24266183e-02, -4.35049757e-02,
#          6.09031972e-03, -9.98171885e-03, -6.23973012e-02,
#          1.07372692e-02, -6.04895223e-03, -7.14661255e-02,
#         -8.45800899e-03, -3.18019874e-02, -1.00518353e-01,
#          2.25892727e-04, -1.89341605e-02, -3.17793749e-02,
#          4.00861092e-02,  2.19178014e-02, -2.59528570e-02,
#          5.84524833e-02, -8.12509656e-02,  2.12029386e-02,
#         -5.02687544e-02,  1.32056857e-02,  1.32681162e-03,
#          2.27062758e-02, -3.45794074e-02,  3.91546786e-02,
#         -2.09433492e-02,  3.24822357e-03,  4.43961024e-02,
#         -9.85358134e-02, -2.88895480e-02, -6.85024215e-03,
#          5.38819097e-02,  6.46110177e-02, -2.45060828e-02,
#          9.21828821e-02, -7.49868974e-02,  1.23994965e-02,
#         -1.00026578e-01, -4.64910679e-02,  6.01569898e-02,
#         -2.46480461e-02, -7.08076060e-02, -2.77271084e-02,
#          9.72610563e-02,  3.85841243e-02, -1.44293215e-02,
#         -7.46876060e-04, -1.04305558e-02, -1.61843076e-02,
#          4.43628244e-02,  9.25995782e-03,  7.14165643e-02,
#          6.37917668e-02,  4.94931154e-02, -6.02567866e-02,
#          4.04805355e-02, -3.42860296e-02, -1.93881392e-02,
#          6.61234260e-02,  6.01589940e-02,  1.09371496e-02,
#         -5.38629945e-03,  1.44580016e-02,  9.25429761e-02,
#         -3.14564258e-02, -1.84351988e-02,  9.91879404e-03,
#         -1.85574368e-02,  1.31281465e-03,  2.26563407e-05,
#          2.02739448e-03,  2.75256820e-02, -4.81927916e-02,
#          5.42825609e-02, -7.32067153e-02,  4.88667339e-02,
#          4.98489924e-02, -9.01142415e-03, -4.68906164e-02,
#         -4.25886661e-02, -8.19523782e-02,  3.87106054e-02,
#          7.85503089e-02,  1.46077052e-32,  1.66706461e-02,
#          5.25494032e-02, -1.82448998e-02, -1.26686115e-02,
#          6.52837232e-02, -2.11777352e-02, -4.06322591e-02,
#          4.14947644e-02, -2.48361286e-02, -1.33068012e-02,
#         -5.46753965e-02, -5.99142280e-04, -4.89243725e-03,
#         -6.27359226e-02, -3.84878181e-02, -6.13544025e-02,
#          8.27405304e-02,  2.34380104e-02, -8.63093510e-03,
#          1.31002879e-02,  6.44215271e-02, -4.41361666e-02,
#         -6.98633343e-02, -7.36060143e-02, -4.33264077e-02,
#          6.96524372e-03, -5.05956821e-02, -1.60911884e-02,
#         -5.66794015e-02,  3.35454172e-03,  5.34114838e-02,
#          2.47761123e-02, -1.47985769e-02, -2.93243285e-02,
#          7.30227977e-02, -1.86834130e-02,  8.13137144e-02,
#         -2.69967336e-02, -5.68056144e-02, -6.59389123e-02,
#         -5.95397688e-03,  2.85312925e-02, -7.85358027e-02,
#         -2.76694074e-03, -3.26468586e-03, -9.28333029e-02,
#         -7.27362633e-02, -3.31903175e-02,  1.01411082e-01,
#          9.79882032e-02, -9.78740007e-02,  1.98667496e-02,
#          2.38837264e-02, -1.81672256e-02, -3.73709053e-02,
#          1.96549576e-03,  6.34426102e-02,  1.18271522e-02,
#         -1.12041505e-02, -3.87316383e-02,  9.32424143e-02,
#          4.26629651e-03, -1.66872405e-02, -6.87463954e-02,
#          1.55120483e-02, -4.97755222e-02,  3.34492959e-02,
#          8.00032243e-02,  2.12281905e-02,  1.34581909e-01,
#         -2.30729971e-02,  5.53858466e-02,  3.07558216e-02,
#         -2.93905493e-02,  2.31905486e-02, -9.34308171e-02,
#          7.58034810e-02, -5.21205226e-03, -5.14523126e-02,
#          3.32689323e-02,  3.67963053e-02, -1.06449798e-02,
#          1.01635531e-02, -2.07651500e-02, -5.85519001e-02,
#          4.79328074e-02,  2.13694833e-02,  8.76213238e-02,
#          3.35493730e-03, -3.80336605e-02, -1.81204714e-02,
#          6.87452592e-03,  5.15879989e-02, -4.75598574e-02,
#         -6.12065159e-02, -1.45483530e-32,  4.12800722e-03,
#          4.59645316e-03, -5.63900769e-02,  4.32465272e-03,
#         -1.09440682e-03,  9.31954570e-03, -2.20268667e-02,
#          5.79564609e-02, -1.44787570e-02,  4.64155599e-02,
#          1.43542871e-01, -6.89756721e-02,  6.09631836e-02,
#         -8.93743858e-02,  2.40919348e-02,  2.06010714e-02,
#         -2.82416046e-02, -6.48315102e-02,  5.64795919e-02,
#         -7.48339668e-03, -3.52058560e-02,  8.51060450e-02,
#          1.30359819e-02,  2.02257708e-02, -1.44390967e-02,
#         -4.63718660e-02,  1.77209731e-02,  1.59105621e-02,
#         -9.51009467e-02, -3.54526788e-02,  2.08696090e-02,
#          3.84385232e-03, -8.77917930e-02,  6.44575506e-02,
#          1.44171612e-02,  3.84729309e-03,  4.70991693e-02,
#          4.94661517e-02,  1.53862564e-02, -2.59578731e-02,
#          9.10894498e-02,  1.83307920e-02, -5.89206219e-02,
#          2.51993146e-02, -3.30373794e-02,  8.23344663e-02,
#          1.74791757e-02,  6.48047403e-02, -1.19674262e-02,
#         -3.31778415e-02,  3.00177317e-02,  3.54220085e-02,
#         -1.39624514e-02,  6.69272989e-02,  3.87919620e-02,
#          6.06916696e-02,  1.17957848e-03, -2.38786284e-02,
#         -1.26930490e-01,  1.13846632e-02,  1.59290060e-02,
#         -1.29426625e-02, -8.63247439e-02,  8.53660703e-03,
#          6.03761636e-02,  1.51122436e-02, -1.19132407e-01,
#          1.15234470e-02,  5.97089268e-02, -3.93345952e-02,
#          1.55673148e-02,  1.04602342e-02, -4.72457036e-02,
#         -2.59243064e-02,  9.98528209e-03,  3.07146013e-02,
#         -7.14844689e-02,  6.98967557e-03, -1.55133186e-02,
#          2.18864325e-02, -2.78145522e-02,  6.92733154e-02,
#         -2.75903475e-02,  2.62429547e-02,  3.52561995e-02,
#         -4.26419415e-02,  7.46284961e-04,  6.59867302e-02,
#         -5.15105650e-02, -3.58434208e-02, -6.53442135e-03,
#         -2.75858492e-02, -1.00125544e-01,  7.83325955e-02,
#         -1.45798773e-02, -6.18457179e-08,  2.00325623e-02,
#          6.59785196e-02, -2.04702597e-02,  1.64043866e-02,
#          7.63001367e-02,  7.32182786e-02,  5.65787451e-03,
#         -6.97761949e-04, -3.63798416e-03,  6.02394454e-02,
#         -3.27187367e-02, -6.45837858e-02, -5.97952567e-02,
#         -1.76695641e-02,  6.10140571e-03, -5.63489553e-03,
#         -1.22972250e-01,  6.35818541e-02, -2.19431613e-02,
#         -1.16406471e-01,  2.34366171e-02, -7.23525435e-02,
#          2.31773816e-02, -6.55986890e-02, -7.42681623e-02,
#          2.60146093e-02,  3.59758511e-02,  7.68432766e-02,
#         -3.08057144e-02, -2.34793816e-02, -6.30426183e-02,
#         -3.62158455e-02, -1.03560099e-02, -4.75602038e-02,
#         -2.87521929e-02,  2.96400692e-02, -5.26895793e-03,
#          5.67889959e-02, -3.74493655e-03,  3.09612677e-02,
#          3.48227136e-02,  3.78607735e-02,  2.10155528e-02,
#          2.70691440e-02,  5.25520556e-02,  7.16229603e-02,
#         -5.53756254e-03,  4.01094146e-02,  5.16276918e-02,
#         -2.67314091e-02,  5.94224073e-02, -4.29224223e-02,
#         -1.19760558e-02,  3.05985250e-02, -7.40331709e-02,
#          1.84221864e-02, -8.64861067e-03, -8.83557424e-02,
#         -5.91984391e-02, -1.00883713e-04,  1.12913661e-01,
#          4.57792962e-03, -4.25971635e-02,  3.22622969e-03],
#        [-9.08220746e-03,  1.30039275e-01, -5.27556948e-02,
#         -1.02350516e-02, -6.75297976e-02, -9.50466990e-02,
#          4.85185981e-02, -9.47349705e-03, -2.13084812e-03,
#          1.87233475e-03,  5.83397076e-02,  4.44539636e-02,
#          7.12240562e-02, -4.32986990e-02, -4.16920297e-02,
#          5.92027716e-02,  4.60821763e-02, -6.13830797e-02,
#         -2.52151322e-02,  4.32086214e-02, -5.89491799e-02,
#         -1.67131494e-03, -7.38696456e-02,  1.84602439e-02,
#          6.78036734e-02,  6.22798763e-02, -1.49626806e-02,
#          2.37330701e-02,  1.17228748e-02,  2.26508789e-02,
#         -4.78888527e-02, -6.45827055e-02, -2.29737628e-02,
#          6.36326894e-02,  5.28414249e-02, -6.83327317e-02,
#          5.78322709e-02, -2.60992646e-02,  2.52554636e-03,
#          1.42765911e-02,  1.73727367e-02, -7.70522747e-04,
#         -6.86686635e-02,  4.30391654e-02, -2.05722661e-03,
#          3.69179957e-02,  5.55713549e-02, -1.70053747e-02,
#          3.44429091e-02,  5.28899729e-02, -3.75934914e-02,
#          4.93239984e-02,  1.01908622e-03,  9.01067071e-03,
#         -1.03128225e-01,  9.01354849e-03,  5.53843193e-02,
#          5.88119812e-02,  7.70880431e-02, -2.29267403e-02,
#         -9.49596521e-04,  1.51682682e-02,  4.68035974e-02,
#          1.20973578e-04, -8.35672393e-02, -4.92034256e-02,
#         -4.12680805e-02, -2.80442145e-02,  3.65302116e-02,
#          1.76587682e-02,  5.94930649e-02, -3.55296605e-03,
#         -5.72861284e-02,  3.33549567e-02,  9.78889763e-02,
#         -3.88248786e-02, -9.92329940e-02, -5.39925620e-02,
#          6.64617941e-02, -5.89256994e-02,  3.96483094e-02,
#         -4.88422532e-03, -4.11456563e-02,  8.65761563e-02,
#         -6.31757304e-02,  4.49261963e-02, -1.47810308e-02,
#          8.21235999e-02,  1.76009964e-02, -4.69383672e-02,
#          4.67320271e-02, -3.61016132e-02,  2.64497790e-02,
#          4.82992232e-02,  1.85631830e-02, -3.11026033e-02,
#          1.47552397e-02, -6.20011911e-02, -7.12177018e-03,
#          8.94641969e-03, -2.77276207e-02,  6.42112419e-02,
#         -9.76543427e-02, -2.55266437e-03,  7.23473355e-02,
#         -9.40286517e-02,  8.31592381e-02, -1.48261599e-02,
#         -3.67440172e-02,  4.61277068e-02, -2.48317793e-02,
#         -1.54204499e-02, -5.39977923e-02, -2.42800973e-02,
#          4.68651205e-02, -3.76712978e-02, -6.20065071e-02,
#          2.84354594e-02, -1.26396447e-01,  9.89488140e-03,
#          1.31281773e-02,  1.59053914e-02,  1.28295636e-02,
#         -7.92737585e-03, -2.62311529e-02, -5.05672991e-02,
#          2.73265522e-02, -3.11218925e-33,  2.10176762e-02,
#          1.53979044e-02,  6.37279749e-02,  1.65238027e-02,
#          7.15340227e-02, -2.62222942e-02,  1.74613893e-02,
#         -1.80667676e-02, -4.20457385e-02,  4.05868590e-02,
#         -2.95151398e-03,  3.41792591e-02,  6.53568432e-02,
#         -1.06967956e-01,  7.27493986e-02,  5.33271246e-02,
#          5.33812679e-02,  8.02431628e-03,  7.27765355e-03,
#          6.67353421e-02,  4.05380651e-02, -1.57962795e-02,
#          1.01968855e-01,  2.59374268e-02, -3.29352841e-02,
#          1.44526297e-02, -8.39286000e-02,  2.99536977e-02,
#          8.12477469e-02, -9.75148566e-03, -1.59049258e-02,
#         -2.47348454e-02,  1.48032987e-02,  7.41941035e-02,
#          1.56551711e-02,  3.00363009e-03,  1.13404468e-01,
#         -6.18463904e-02, -5.42236753e-02,  3.96914743e-02,
#         -3.20439856e-03, -5.68466745e-02,  5.12020141e-02,
#         -2.87401909e-03, -6.60872310e-02, -6.60175225e-03,
#         -4.09216657e-02,  1.15509331e-02, -2.12300457e-02,
#          8.20629150e-02, -9.29427221e-02,  2.96932347e-02,
#          1.83772538e-02, -3.86051508e-03, -3.92205603e-02,
#          3.93136498e-03, -2.01114211e-02, -3.93377654e-02,
#         -1.11585511e-02, -5.59599651e-03,  1.62631646e-02,
#          6.48474917e-02,  2.48070620e-02, -2.49167643e-02,
#         -8.27951655e-02, -1.17445469e-01,  1.36739211e-02,
#         -4.98043559e-02,  7.56866634e-02,  6.00601034e-03,
#         -4.68833111e-02,  1.37707572e-02,  6.18149228e-02,
#          2.28249859e-02, -4.20788042e-02,  2.90793106e-02,
#         -2.13195346e-02,  1.25170294e-02, -1.58704668e-02,
#         -4.40216996e-03,  6.08482324e-02, -9.53699946e-02,
#         -5.92659041e-03,  1.81380819e-04, -1.12819448e-01,
#          7.15292245e-02, -1.05405428e-01,  7.40236649e-03,
#         -2.43040491e-02,  7.81292915e-02, -2.29443889e-02,
#          5.98855242e-02, -2.65169144e-02,  1.40888933e-02,
#         -5.24675325e-02,  3.95403268e-35, -5.82680618e-03,
#         -9.77606326e-03,  1.14575364e-02, -7.19535276e-02,
#          9.29484889e-02, -1.04548745e-02, -6.84540942e-02,
#          3.25114504e-02, -6.10480411e-03, -2.90172994e-02,
#          6.42282143e-02, -6.81057852e-03,  6.92076087e-02,
#         -7.14609995e-02, -2.50622258e-03,  5.47156483e-02,
#         -1.09309449e-05,  4.32232171e-02, -4.90597598e-02,
#         -1.99718084e-02, -7.91710317e-02,  4.96524274e-02,
#         -1.13588907e-02, -3.29505466e-02, -2.82125808e-02,
#          4.91848439e-02,  2.65164841e-02, -7.44589558e-03,
#          3.21837813e-02,  2.65936963e-02,  7.25485310e-02,
#         -1.22614801e-02, -1.39019126e-02,  3.86513770e-02,
#         -3.05636097e-02, -4.60575595e-02,  8.00826550e-02,
#          4.66559567e-02, -4.62550819e-02, -9.24284831e-02,
#          3.07189655e-02,  6.45621791e-02,  2.94253416e-02,
#         -1.65764559e-02, -1.33449323e-02, -3.53342220e-02,
#         -6.05267473e-03, -1.92572852e-03,  1.05050225e-02,
#          2.83620879e-02,  5.00474274e-02, -4.84405160e-02,
#          1.49582982e-01,  1.95890851e-02, -6.44527609e-04,
#          1.81442332e-02,  1.19423181e-01, -3.78811620e-02,
#          7.50600621e-02, -5.65818185e-03, -4.62590065e-03,
#         -4.13699262e-03, -6.21703751e-02,  4.71085608e-02,
#         -5.51818870e-03,  1.32480394e-02, -8.18343554e-03,
#         -2.20693331e-02,  4.15597036e-02, -4.83361399e-03,
#          1.21741267e-02,  6.72821945e-04,  5.69307581e-02,
#         -8.71304143e-03,  1.25069693e-01, -6.95217624e-02,
#         -1.11355200e-01,  2.48699598e-02, -5.42907752e-02,
#          6.17703889e-03,  1.07396081e-01, -6.31492063e-02,
#         -5.63528277e-02,  9.22991522e-03,  6.40114471e-02,
#         -5.33823110e-02,  8.54583830e-03, -9.18629169e-02,
#          4.80809389e-03, -3.91735584e-02, -4.88125905e-02,
#         -1.19019501e-01, -1.06080942e-01,  1.07142292e-01,
#          6.87461346e-02, -1.44682328e-08, -1.53902173e-03,
#         -5.67629561e-02, -3.06830592e-02,  5.28246462e-02,
#          1.12762049e-01, -8.87020584e-03, -7.78775141e-02,
#         -6.83962479e-02, -4.95948717e-02, -2.93196160e-02,
#          1.74915288e-02,  4.99280170e-03,  3.07702851e-02,
#         -4.03786637e-02, -7.15771392e-02, -4.70521003e-02,
#          2.45921984e-02, -1.06422506e-01,  2.92301867e-02,
#         -1.37384236e-03, -9.01069783e-04, -2.51062885e-02,
#         -7.47966468e-02, -5.06681576e-02,  7.62836710e-02,
#          5.18232137e-02, -1.86376851e-02,  5.40206246e-02,
#         -4.11217920e-02,  3.64418030e-02, -8.76831561e-02,
#         -5.86261302e-02,  2.04861909e-02,  1.57247912e-02,
#         -1.35220394e-01, -3.34420353e-02,  3.72842178e-02,
#         -3.97885405e-02, -3.06372978e-02, -9.04950798e-02,
#          1.13008795e-02,  4.29564044e-02,  3.39670032e-02,
#          1.01201329e-02, -2.23362539e-02, -4.33646794e-03,
#          1.20124053e-02,  4.52400260e-02,  9.26024392e-02,
#         -7.31420219e-02, -2.78646294e-02, -1.96059421e-02,
#         -5.10010403e-03,  9.55215916e-02,  3.93618569e-02,
#          2.24670465e-03, -4.02989946e-02, -1.02186929e-02,
#         -1.00236453e-01,  3.53214704e-02,  4.27119769e-02,
#          2.01410353e-02, -5.11709563e-02, -2.93029454e-02]], dtype=float32)

# %%
X= filtered_embeddings
y = df_non_legacy['target_label']


from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42)

clf = LogisticRegression(max_iter= 1000)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#                 precision    recall  f1-score   support
#
# Critical Error       0.97      1.00      0.98        32
#          Error       1.00      0.97      0.99        37
#    HTTP Status       1.00      1.00      1.00        64
# Resource Usage       1.00      1.00      1.00        39
# Security Alert       1.00      1.00      1.00       102
#
#       accuracy                           1.00       274
#      macro avg       0.99      0.99      0.99       274
#   weighted avg       1.00      1.00      1.00       274

# %%
import joblib

# %%
joblib.dump(clf, 'sample_data/log_classifier.joblib')
# Out:
# ['sample_data/log_classifier.joblib']

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# sample_data/  synthetic_logs.csv
